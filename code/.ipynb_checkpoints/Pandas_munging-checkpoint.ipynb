# %%
# %matplotlib inline
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

cwd = os.getcwd()
print("Current working directory is" + cwd)

relativepath = os.path.join('..', 'data', 'Montreal', 'comptagevelo2012.csv')
print(relativepath)

bikes_df = pd.read_csv(relativepath, parse_dates=['Date'], dayfirst=True, index_col=['Date'])
# Out:
# Current working directory is/Users/rmorriss/Documents/datahum/code
# ../data/Montreal/comptagevelo2012.csv

# %%
# bikes_df.head()
bikes_df['Unnamed: 1'].value_counts()
# Out:
# 00:00    366
# Name: Unnamed: 1, dtype: int64

# %%
del bikes_df['Unnamed: 1']
bikes_df.head()
# Out:
#             Rachel / Papineau  Berri1  Maisonneuve_2  Maisonneuve_1  Brébeuf  \
# Date
# 2012-01-01                 16      35             51             38      5.0
# 2012-01-02                 43      83            153             68     11.0
# 2012-01-03                 58     135            248            104      2.0
# 2012-01-04                 61     144            318            116      2.0
# 2012-01-05                 95     197            330            124      6.0
#
#             Parc  PierDup  CSC (Côte Sainte-Catherine)  Pont_Jacques_Cartier
# Date
# 2012-01-01    26       10                            0                  27.0
# 2012-01-02    53        6                            1                  21.0
# 2012-01-03    89        3                            2                  15.0
# 2012-01-04   111        8                            1                  19.0
# 2012-01-05    97       13                            2                  16.0

# %%
bikes_df['Berri1'].plot()

# %%
bikes_df.plot(figsize=(15,10))

# %%
del bikes_df[23092.0]

# %%
bikes_df.sort_values('Pont_Jacques_Cartier', ascending=False)
# Out:
#             Rachel / Papineau  Berri1  Maisonneuve_2  Maisonneuve_1  Brébeuf  \
# Date
# 2012-03-18               2477    1940           1923           1036    162.0
# 2012-03-19               2058    1821           2581           1278    104.0
# 2012-05-13               3496    2741           3086           1703   1901.0
# 2012-08-03               5031    5612           6451           3306      NaN
# 2012-06-22               5263    5404           6666           3612      NaN
# 2012-10-06               1775    1296           1578            933      NaN
# 2012-07-11               5474    6424           7366           3921      NaN
# 2012-08-04               4467    4213           4407           2019      NaN
# 2012-07-25               5059    6107           7065           3786      NaN
# 2012-07-08               5535    4677           4457           2407      NaN
# 2012-07-10               5952    6518           7447           4064      NaN
# ...

# %%
bikes_df.head()
# Out:
#             Rachel / Papineau  Berri1  Maisonneuve_2  Maisonneuve_1  Brébeuf  \
# Date
# 2012-01-01                 16      35             51             38      5.0
# 2012-01-02                 43      83            153             68     11.0
# 2012-01-03                 58     135            248            104      2.0
# 2012-01-04                 61     144            318            116      2.0
# 2012-01-05                 95     197            330            124      6.0
#
#             Parc  PierDup  CSC (Côte Sainte-Catherine)  Pont_Jacques_Cartier
# Date
# 2012-01-01    26       10                            0                  27.0
# 2012-01-02    53        6                            1                  21.0
# 2012-01-03    89        3                            2                  15.0
# 2012-01-04   111        8                            1                  19.0
# 2012-01-05    97       13                            2                  16.0

# %%
fall_bikes = bikes_df['Date' > 2012-08-01 and 'Date' < 2012-11-01]
# Out:
#   File "<ipython-input-6-b7b1ddd163e4>", line 1
#     fall_bikes = bikes_df['Date' > 2012-08-01 and 'Date' < 2012-11-01]
#                                          ^
# SyntaxError: invalid token
